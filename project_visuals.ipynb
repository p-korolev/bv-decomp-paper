# %%
import bias_variance_utils as ut

# %%
# experiment build
import bias_variance_utils as ut
exp = ut.run_experiment(
    
    true_func = "sin",
    noise = 0.35,
    max_degree = 28,
    n_seeds = 200,
    x_min=-1.5,
    x_max=1.5,
    n_train=250

)

ut.plot_data_generating_process(results=exp)

ut.plot_model_showcase(results=exp, degrees_to_show=[5, 11, 28], y_lim=(-1.5,1.5))

ut.plot_train_vs_test_error(results=exp, show_noise_floor=True)

ut.plot_bias_variance_decomposition(results=exp, show_stacked=False)

# %%
# Bad parameters example
import bias_variance_utils as ut
exp = ut.run_experiment(
    
    true_func = "cos",
    noise = 0.35,
    max_degree = 7,
    n_seeds = 200,
    x_min=-1.5,
    x_max=1.5,
    n_train=15

)

ut.plot_data_generating_process(results=exp)

#ut.plot_model_showcase(results=exp, degrees_to_show=[5, 11, 22], y_lim=(-1.1,1.1))

ut.plot_train_vs_test_error(results=exp)

ut.plot_bias_variance_decomposition(results=exp, show_stacked=False)

# %%
exp = ut.run_experiment(
    
    true_func = "cubic",
    noise = 0.5,
    max_degree = 20,
    n_seeds = 200,
    x_min=-1,
    x_max=1,
    n_train=250

)

ut.plot_data_generating_process(results=exp)

ut.plot_model_showcase(results=exp, degrees_to_show=[1, 3, 11], y_lim=(-1.1,1.1))

ut.plot_train_vs_test_error(results=exp)

ut.plot_bias_variance_decomposition(results=exp, show_stacked=False)

# %%
# experiment build
import bias_variance_utils as ut
exp = ut.run_experiment(
    
    true_func = "sin",
    noise = 0.35,
    max_degree = 25,
    n_seeds = 200,
    x_min=-1.5,
    x_max=1.5,
    n_train=250

)

# %%
ut.plot_train_error(results=exp, show_noise_floor=True, figsize=(11,5), custom_ticks=[1, 11,25])
ut.plot_train_vs_test_error(results=exp, show_noise_floor=True, figsize=(11,5))
ut.plot_model_showcase(results=exp, degrees_to_show=[5, 11, 25], y_lim=(-1.5,1.5))
ut.plot_bias_variance_decomposition(results=exp, show_stacked=False)
ut.plot_data_generating_process(results=exp, n_samples_shown=3, figsize=(11,5))

# %%
# poor parameters
exp = ut.run_experiment(
    
    true_func = "sin",
    noise = 0.35,
    max_degree = 7,
    n_seeds = 200,
    x_min=-1.5,
    x_max=1.5,
    n_train=15

)

# %%
ut.plot_train_vs_test_error(results=exp, show_noise_floor=True, figsize=(11,5))
